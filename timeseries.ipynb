# %%
#pandas data reader dahil et
# %pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf

# %%
#zaman serisi verisi
df = yf.download('AAPL','2016-01-01','2021-01-01')
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2016-01-04  25.652500  26.342501  25.500000  26.337500  23.977476  270597600
# 2016-01-05  26.437500  26.462500  25.602501  25.677500  23.376617  223164000
# 2016-01-06  25.139999  25.592501  24.967501  25.174999  22.919144  273829600
# 2016-01-07  24.670000  25.032499  24.107500  24.112499  21.951855  324377600
# 2016-01-08  24.637501  24.777500  24.190001  24.240000  22.067923  283192000

# %%
df.shape
# Out:
# (1259, 6)

# %%
closed = df["Close"]
closed.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
closed.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#zaman değişkeni bilgisini ifade eder
closed.index = pd.DatetimeIndex(closed.index)
closed.plot()
# Out:
# <Axes: xlabel='Date'>
